# %%
#let's setup the config class for the project
from src.config import load_config
config = load_config()
# Out:
# 2026-08-29 18:58:41,006 | INFO | src.config | Loaded the yaml file from /Users/nikhilnarsipalli/Documents/UNIVERSITY/Projects/MLOps /2nd day project/configs/config.yaml
# 2026-08-29 18:58:41,007 | INFO | src.config | Created config class for DatasetConfig
# 2026-08-29 18:58:41,007 | INFO | src.config | Created config class for ModelConfig
# 2026-08-29 18:58:41,007 | INFO | src.config | Created config class for TrainingConfig
# 2026-08-29 18:58:41,008 | INFO | src.config | Created config class for UnitTest
# 2026-08-29 18:58:41,008 | INFO | src.config | Created config class for DataPath

# %%
#Now, let's import the required libraries
import pandas as pd
from pathlib import Path

#Raw data path
path = Path.cwd().parent
path = path.joinpath(config.dataPath.root_dir, config.dataPath.raw_data_dir, config.dataPath.datasetName)

# %%
df = pd.read_csv(path, encoding='latin-1')
print(df.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
len(df.columns)
# Out:
# 21

# %%
for column in df.columns:
    print(f"{column}: {df[column].nunique()} unique values, while total values are {len(df[column])} and null values are {df[column].isnull().sum()}")
# Out:
# customerID: 7043 unique values, while total values are 7043 and null values are 0
# gender: 2 unique values, while total values are 7043 and null values are 0
# SeniorCitizen: 2 unique values, while total values are 7043 and null values are 0
# Partner: 2 unique values, while total values are 7043 and null values are 0
# Dependents: 2 unique values, while total values are 7043 and null values are 0
# tenure: 73 unique values, while total values are 7043 and null values are 0
# PhoneService: 2 unique values, while total values are 7043 and null values are 0
# MultipleLines: 3 unique values, while total values are 7043 and null values are 0
# InternetService: 3 unique values, while total values are 7043 and null values are 0
# OnlineSecurity: 3 unique values, while total values are 7043 and null values are 0
# OnlineBackup: 3 unique values, while total values are 7043 and null values are 0
# DeviceProtection: 3 unique values, while total values are 7043 and null values are 0
# ...

# %%
for column in df.columns:
    print(f"{column} --> {type(df[column][0])} --->     {df[column][0]}")
# Out:
# customerID --> <class 'str'> --->     7590-VHVEG
# gender --> <class 'str'> --->     Female
# SeniorCitizen --> <class 'numpy.int64'> --->     0
# Partner --> <class 'str'> --->     Yes
# Dependents --> <class 'str'> --->     No
# tenure --> <class 'numpy.int64'> --->     1
# PhoneService --> <class 'str'> --->     No
# MultipleLines --> <class 'str'> --->     No phone service
# InternetService --> <class 'str'> --->     DSL
# OnlineSecurity --> <class 'str'> --->     No
# OnlineBackup --> <class 'str'> --->     Yes
# DeviceProtection --> <class 'str'> --->     No
# TechSupport --> <class 'str'> --->     No
# StreamingTV --> <class 'str'> --->     No
# StreamingMovies --> <class 'str'> --->     No
# Contract --> <class 'str'> --->     Month-to-month
# PaperlessBilling --> <class 'str'> --->     Yes
# PaymentMethod --> <class 'str'> --->     Electronic check
# MonthlyCharges --> <class 'numpy.float64'> --->     29.85
# TotalCharges --> <class 'str'> --->     29.85
# ...

# %%
# Let's see how many of each type of columsn are present in the dataset
df.dtypes.value_counts()
# Out:
# str        18
# int64       2
# float64     1
# Name: count, dtype: int64

# %%
"""
Observations:
1. Data set has 21 columns and 7043 rows
2. The does not have any null values
3. 18 columns - string, 2 columns - int64, 1 column - float64
"""
# Out:
# ''
